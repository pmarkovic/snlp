# %% [markdown]
# # Assignment 8
#
# Name 1: Rricha Jalota <br/>
# Id 2: 7010592 <br/>
# Email id 1: rrja00001 <br/>
#
# Name 2: Pavle Markovic <br/>
# Id 2: 7007913 <br/>
# Email id 2: pama00002 <br/>
#
# **Instructions:** Read each question carefully. <br/>
# Make sure you appropriately comment your code wherever required. Your final submission should contain the completed Notebook and the Python files for exercise 1. There is no need to submit the data files. <br/>
# Upload the zipped folder in Teams. Make sure to click on "Turn-in" after your upload your submission, otherwise the assignment will not be considered as submitted. Only one from the group should make the submisssion.
#
# ---

# %% [markdown]
# ## Exercise 1: Document Classification Warm-Up (4 points)
#
# In this exercise you will explore the Reuters News corpus and apply basic feature selection techniques to it. You can download the reuters corpus and English stop words via [NLTK](https://www.nltk.org/):

# %%
# !pip install nltk
import nltk
nltk.download('reuters')
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (3.6.2)
# Requirement already satisfied: click in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from nltk) (8.0.1)
# Requirement already satisfied: regex in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from nltk) (2021.4.4)
# Requirement already satisfied: tqdm in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from nltk) (4.59.0)
# Requirement already satisfied: joblib in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: importlib-metadata in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from click->nltk) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/pavle/anaconda3/envs/snlp/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.4.1)
# [nltk_data] Downloading package reuters to /home/pavle/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pavle/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# It consists of articles from [Reuters](https://de.wikipedia.org/wiki/Reuters) mapped to one of
# Files and categories (classes) can be accessed easily. Although there is a train/test split, we will use the whole corpus for this exercise.

# %%
from nltk.corpus import reuters, stopwords
stop_words = stopwords.words('english')
print(reuters.categories())
print("# of categories: {}".format(len(reuters.categories())))
reuters.fileids()[:10]
# Out:
# ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee', 'copper', 'copra-cake', 'corn', 'cotton', 'cotton-oil', 'cpi', 'cpu', 'crude', 'dfl', 'dlr', 'dmk', 'earn', 'fuel', 'gas', 'gnp', 'gold', 'grain', 'groundnut', 'groundnut-oil', 'heat', 'hog', 'housing', 'income', 'instal-debt', 'interest', 'ipi', 'iron-steel', 'jet', 'jobs', 'l-cattle', 'lead', 'lei', 'lin-oil', 'livestock', 'lumber', 'meal-feed', 'money-fx', 'money-supply', 'naphtha', 'nat-gas', 'nickel', 'nkr', 'nzdlr', 'oat', 'oilseed', 'orange', 'palladium', 'palm-oil', 'palmkernel', 'pet-chem', 'platinum', 'potato', 'propane', 'rand', 'rape-oil', 'rapeseed', 'reserves', 'retail', 'rice', 'rubber', 'rye', 'ship', 'silver', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'strategic-metal', 'sugar', 'sun-meal', 'sun-oil', 'sunseed', 'tea', 'tin', 'trade', 'veg-oil', 'wheat', 'wpi', 'yen', 'zinc']
# # of categories: 90
# ['test/14826',
#  'test/14828',
#  'test/14829',
#  'test/14832',
#  'test/14833',
#  'test/14839',
#  'test/14840',
#  'test/14841',
#  'test/14842',
#  'test/14843']

# %% [markdown]
# Each document belongs to one or more categories. For the sake of simplicity we map each document to the first of its categories.

# %%
print(reuters.categories('test/14833'))
category = reuters.categories('test/14833')[0]
category
# Out:
# ['palm-oil', 'veg-oil']
# 'palm-oil'

# %% [markdown]
# **1.1: Categories (1.5 points)**
#
# 1. Load data into the `Corpus` class. We suggest to give an attribute `documents` that contains a list of `Document` objects. Preprocessing steps (tokenization, lowercasing, stopword removal) should happen within the `Document` objects. As always, you can deviate from that if you find it more convenient. (1 point)
# 2. Implement the method `category_frequencies` in the `Corpus` class. It should calculate the absolute frequencies of each category in the whole corpus. (0.25 points)
# 3. Plot categories vs. their frequency on a log-log scale. Do so by implementing the function `plot_category_frequencies`. What can you say about the distribution the category frequencies you observe? (0.25 points)
#
#
# **Answer:**
# - It can be observed that the distribution of categories follows Zipfian distribution to some degree.

# %%
from importlib import reload
import exercise_1
exercise_1 = reload(exercise_1)

corpus = exercise_1.Corpus(
    documents=[exercise_1.Document(fileid, reuters.raw(fileid), reuters.categories(fileid), stop_words=stop_words) for fileid in reuters.fileids()],
    categories=reuters.categories()
)

exercise_1.plot_category_frequencies(corpus.category_frequencies())
# Out:
# [nltk_data] Downloading package reuters to /home/pavle/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/pavle/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **1.2 Document Frequency (1.5 points)**
#
# A term's document frequency (DF) is given by:
#
# \begin{equation}
# DF_{c_k}(t_i) =
# \frac{
# \text{# of times $t_i$ occurs in $C_k$}
# }{
# \text{# of documents of category $C_k$}
# }
# \end{equation}
#
# 1. Find the 10 most frequent terms of the `housing ` category. Do so by implementing the method `term_frequencies` in the `Corpus` class. (0.5 points)
# 2. For these 10 terms, calculate their DF in the `housing` category as well as in the whole corpus (over all categories). Do so by implementing the method`df` in the `corpus` class. Plot the results by implementing the function `plot_dfs`. (0.5 points)
# 3. Is DF a good predictor for a category? Explain in 2-3 sentences. (0.5 points)
#
#
# **Answer:**
# - It can be good predictor, since using DF words relevant to the category can be expected to have higher frequencies compared to their overall frequencies in whole corpus. However, DF does not have a protection from noise (i.e. words that appear many times in every document) which might not be relevant to the category (e.g. u.s. or pct in the graph below).

# %%
most_common_housing = corpus.term_frequencies('housing').most_common(10)
most_common_housing = [term for term, _ in most_common_housing]

dfs_housing = [corpus.df(term, category='housing') for term in most_common_housing]
dfs_all = [corpus.df(term) for term in most_common_housing]

exercise_1.plot_dfs(most_common_housing, dfs_housing)
exercise_1.plot_dfs(most_common_housing, dfs_all)

# %% [markdown]
# **1.3 Pointwise Mutual Information (1 point)**
#
# PMI is given by:
# \begin{equation}
# PMI(x;y) = \log_2 \frac{p(x,y)}{p(x)p(y)}
# \end{equation}
#
# 1. Give an interpretation of PMI. When will it be large, when will it be small? What are its upper and lower bound? (0.25 points)
# 2. Calculate PMI of the `housing` category and each of the 10 most frequent terms from that category. Do so by implementing the method `pmi` in the `Corpus` class. Plot the PMI values. Do so by implementing the function `plot_pmis`. (0.5 points)
# 3. What does the plot tell you about the suitability of the most frequent words of a category as a feature for text classification? Come up with an improved measure that makes use of both the document frequency and PMI (it need not be derived formally from PMI, but it should be motivated by your findings). (0.25 points)
#
# **Answers:**
#
# - PMI formula $PMI(x;y) = \log_2 \frac{p(x,y)}{p(x)p(y)}$ can be interpretated as $PMI(x;y) = \log_2 \frac{p(x|y)}{p(x)} = \log_2 p(x|y) - \log_2 p(x)$. From the latest, it can be observed that $PMI$ value between two terms $x$ and $y$ increases as $p(x)$ decreases, assuming constant $p(x|y)$, while decreases as $p(x)$ increases. Therefore, it can have both positive and negative values (zero value if terms $x$ and $y$ are independent). Lastly, bounds for PMI values are: $-\infty \leq PMI(x;y) \leq min[-\log_2 p(x), -\log_2 p(y)]$
# - The plot shows that only two out of ten (assuming 0.5 treshold) most common terms from the housing category are relevant to the category, therefore, using just DF for feature selection can be misleading. One potential improved measure can be a "weighted DF" where PMI values would be used as weights for selected DF terms.

# %%
pmis = [corpus.pmi('housing', term) for term in most_common_housing]
exercise_1.plot_pmis('housing', most_common_housing, pmis)

# %% [markdown]
# ## Exercise 2 $\chi^2$ (2p)
#
# Study the usage of $\chi^2$ statistics online. A very brief overview with examples can be found on [Wikipedia](https://en.wikipedia.org/wiki/Chi-squared_test).
#
# **2.1 $\chi^2$ Introduction (1.25 points)**
#
# 1. How can you turn a numerical feature into a categorical one? What are the parameters of this decision? What are some features (at least 3) one may encounter in NLP? (0.25 points)
# 2. With the following knowledge of binary features, what's the expected count of $c(A \cap B), c(\neg A \cap B), c(A \cap \neg  B), c(\neg A \cap \neg B)$? \\
# Total count $N = 100$, $c(A) = 35, c(B) = 61$. (0.25 points)
# 3. Using the given observations compute the $\chi^2$ statistics and the respective probability of the features $B$ and $C$. (0.5 points)
#
# ||A|$\neg$ A|
# |-|-|-|
# |B|6|55|
# |$\neg$ B|29|10|
#
# ||A|$\neg$ A|
# |-|-|-|
# |C|21|40|
# |$\neg$ C|14|25|
#
# 4. Based on your research of $\chi^2$, what does the computed probability signify (in terms of hypotheses)? What is the hypothesis? Would you say that $B$ and $C$ are good features to decribe $A$? (0.25 points)
#
#
# **2.2 $\chi^2$ Feature selection (0.75 points)**
#
# 1. Given the set of categorical features $F$ and one specific target feature $f_0$, how can you use the $\chi^2$ statistics to select the most predictive feature? (0.25 points)
# 2. If you know all the features in $F$ are **not** pair-wise independent, how do you select $k$ features to describe $f_0$ together? (0.25 points)
# 3. If you know all the features in $F$ are pair-wise independent, how do you select $k$ features to describe $f_0$ together? (Try to be computationally efficient and therefore provide a different algorithm than for the previous question.) (0.25 points)

# %% [markdown]
# ### Answers
# 2.1.1 We can turn a numerical feature into categorical one by grouping it into ranges. Eg. numbers occuring in a range of 0-100 can be grouped into 10 categories - [0, 10), [10,20),...,[90,100]. Numerical features in NLP that can be converted to categorical scale are: i) frequency of n-grams, ii) count of content/function words, iii) term frequency, inverse-document frequency and tf-idf
#
# 2.1.2 $c(A \cap B) = 61 * 35 / 100 = 21.35 , c(\neg A \cap B) = 61 * 65 / 100 = 39.65, c(A \cap \neg  B) = 35 * 39 /100 = 13.65, c(\neg A \cap \neg B) = 65 * 39 / 100 = 25.35$
#
# 2.1.3 $\chi^2$ for B = (6 - 21.35)²/21.35 + (55-39.65)²/39.65 + (29-13.65)²/13.65 + (10-25.35)²/25.35 = 11.04+5.94+9.29+17.26 = 43.53.
# Degrees of freedom = (R-1)(C-1) = 1, The P-Value is < .000010. The result is significant at p < .05. So, we reject the null hypothesis that there is no relationship between A and B.
#
# $\chi^2$ for C = (21 - 21.35)²/21.35 + (40-39.65)²/39.65 + (14-13.65)²/13.65 + (25-25.35)²/25.35 = 0.022633.
# The P-Value is 0.880502. The result is not significant at p < .05. Therefore, we accept the null hypothesis that there is no relationship between A and C.
#
#
# 2.3.4 Chi-square test is used to determine whether there is any relationship between 2 categorical variables. The null hypothesis is there is no relationship between the variables (A, B and A, C). Since the p-value is significant in case of B, we reject the null hypothesis. Hence, B is a good feature to describe A but C is not, since the result is not significant (as discussed above).
#
#
# 2.2.1 We can select k features by applying $\chi^2$-test on each feature in F and the target feature $f_0$, thereby checking if the feature in $F$ has any relationship with $f_0$ or is independent. (similar to the way, we select features in Q 2.1)
#
# 2.2.2 We first apply $\chi^2$-test or ANOVA on the features in $F$ to identify features that are independent to each other. Then we repeat the process as described in 2.2.1.

# %% [markdown]
# ## Exercise 3: Authorship Identification (4 points)
#
# The science of *stylometry* assumes that authors have unconscious writing habits. Therefore, the words and grammar in a text become reliable indicators of the author of the text. Various research techniques have tried to do a feature-level analysis for the task of authorship identification/attribution.
#
# **3.1 (1 point)**
#
# In Chapter 6, you studied different types of classification. For the particular problem of authorship identification, suggest how you could formulate this task for each of the following categories (1 sentence each)
#
# - Binary classification
# - Multi-class classification
# - Flat classification
# - Hierarchical classification
# - Single category classification
# - Multi-category classification
# - Clustering
#
# **3.2 (2.5 points)**
#
# Read this [paper](https://dl.acm.org/doi/pdf/10.3115/1220355.1220443) which does a feature study for authorship identification. Answer the following questions (1-3 sentences each):
#
# 1. What are the 6 categories of features extracted for the task? Explain in 1 sentence each. (0.5 points)
# 2. What does the author observe in comparison to the baseline? (0.5 points)
# 3. The author suggests using [SVM](https://en.wikipedia.org/wiki/Support-vector_machine)s as the classifier. What are the advantages offered by SVMs which guarantee a high accuracy in this problem? (0.5 point)
# 4. The author concludes several possible scopes of improvement. Based on what you have studied so far, suggest if any improvements can be made in the given study w.r.t. (1 point)
#   - Feature selection
#   - Usage of n-gram features
#   - Any other approach other than the above two
#
# **3.3 (0.5 points)**
#
# State 3 real-life, contemporary applications where authorship identification/verification/attribution is useful.

# %% [markdown]
# ## Exercise 3 answers:
#
# **3.1**
# - Binary classification - Check if an author wrote the given text or not.
# - Multi-class classification - Among multiple authors, who is the most likely candidate as the writer of the given text.
# - Flat classification - Identify the most probable label among many (author1, author2, genre1, genre2, etc.).
# - Hierarchical classification - first classifiy an excerpt based on its genre, then identify which author belonging to that genre of writing wrote it.
# - Single category classification - Among multiple authors, who is the most likely candidate as the writer of the given text.
# - Multi-category classification - Identify all (zero to N) authors which works have been used in the given text.
# - Clustering - Identify clusters of given texts which belongs to certain authors.
#
# **3.2** <br>
# 1.  **Length features** - Average length of sentences, noun-phrases, adjectival/adverbial phrases, and subordinate clauses per document.
# **Function word frequencies** - Calculate frequencies of lemmatized function words with changing all personal pronouns to perspro.
#  **POS trigrams** - Calculate frequencies of POS trigrams.
# **Syntactic productions** - Extract context-free grammer and calculate frequencies of its elements per document.
# **Semantic information** - Extract semantic binary information and semantic modification relations, while calculating frequencies per document of modification relations.
# **N-gram frequency** - Calculate frequencies of different n-grams per document, after neutralizing proper nouns and personal pronouns.
# 2.
# 3. SVMs scale relatively well to high-dimensional data. So even when large amount of features are given to the model, SVM finds an optimal hyperplane to distinguish between classes.
# 4.
#   - Feature selection - Running a statistical test like $\chi^2$-test to identify independent and redundant features.
#   - Usage of n-gram features
#   - Any other approach other than the above two
#
# **3.3**
# - Plagiarism detection (checking if text is original work of an author).
# - Book recommendation (identifiying authors similar to the referent one).
# - Fake text detection (checking if an author really wrote the article).

# %% [markdown]
# ## Bonus (1.5 points)
#
# Consider the two plots given below.
#
# * For Plot 1 and Plot 2, are any or both of the features 1 and 2
# 1. redundant
# 2. useful
# 3. irrelevant
#
#     for a task like clustering? Explain your choice from the above 3. (1 point)
#
# ![Plots](bonus_features.png "Plots 1 and 2")
#
# * Draw/create a plot which shows features 1 and 2 as the remaining of the 3 choices stated above. Explain your reasoning in 1-2 sentences. (0.5 point)
#
#
# **Answers:**
# - For Plot 1, both features are useful, while for Plot 2 feature 1 is useful and feature 2 is irrelevant. In case of Plot 1, both features can help with a certain task since they both help differenciate between two clusters of data points. In case of Plot 2, feature 2 is not helpful in determing clusters since data points of both categories lay in the same value range.
# - In the plot below data points follow linear relation, therefore, using a dimensionality reduction method one feature can be removed as redundant without lossing much information and stil been able to achieve good results on the task.
#
# ![Plot3](plot.png "PLot 3")
